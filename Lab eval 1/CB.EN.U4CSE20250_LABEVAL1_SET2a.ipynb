# %% [markdown]
# # Q1

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DS_SEM5/Lab Eval 1/Copy of IoTBotNetDataset.csv')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# ...

# %% [markdown]
# # Q2

# %%
df.drop(['attack'],axis=1)
df.columns
df.drop("sport", axis='columns')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-0065bb9ef3ae> in <module>
# ----> 1 df.drop(['attack'],axis=1)
#       2 df.columns
#       3 df.drop("sport", axis='columns')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %% [markdown]
# **attack has been deleted so we get error**

# %% [markdown]
# # Q3

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 996294 entries, 0 to 998552
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   pkSeqID                           996294 non-null  float64
#  1   stime                             996294 non-null  float64
#  2   flags                             996294 non-null  object
#  3   flgs_number                       996294 non-null  float64
#  4   proto                             996294 non-null  object
#  5   proto_number                      996294 non-null  float64
#  6   saddr                             996294 non-null  object
#  7   sport                             996294 non-null  object
#  8   daddr                             996294 non-null  object
#  9   dport                             996294 non-null  object
#  10  pkts                              996294 non-null  float64
# ...

# %% [markdown]
# As we can see all columns have as many values as rows, so deletion is successful

# %% [markdown]
# # Q4

# %%
print(df['AR_P_Proto_P_SrcIP'].describe())
# Out:
# count    996294.000000
# mean          1.586264
# std          28.424955
# min           0.003857
# 25%           0.177890
# 50%           0.232549
# 75%           0.340498
# max       15748.000000
# Name: AR_P_Proto_P_SrcIP, dtype: float64

# %% [markdown]
# As we can see here, max value is much higher than mean, hence we can say 'AR_P_Proto_P_SrcIP' has an outlier

# %%
print(df['N_IN_Conn_P_SrcIP'].describe())
# Out:
# count    996294.000000
# mean         83.344447
# std          23.707828
# min           1.000000
# 25%          70.000000
# 50%         100.000000
# 75%         100.000000
# max         100.000000
# Name: N_IN_Conn_P_SrcIP, dtype: float64

# %% [markdown]
# As we can see here, the mean is quite close to max value, so we can say there are no outliers

# %% [markdown]
# # Q5

# %%
x=df['mean']
y=df['min']
x.corr(y)
# Out:
# 0.6295401142104426

# %% [markdown]
# # Q6

# %%
print(df.describe())
# Out:
#              pkSeqID         stime    flgs_number   proto_number  \
# count  996294.000000  9.962940e+05  996294.000000  996294.000000
# mean   500192.610047  1.528083e+09       1.808432       1.765398
# std    287941.356653  1.754146e+03       1.107502       0.972087
# min         1.000000  1.528081e+09       1.000000       1.000000
# 25%    251333.250000  1.528081e+09       1.000000       1.000000
# 50%    500406.500000  1.528081e+09       2.000000       1.000000
# 75%    749479.750000  1.528085e+09       2.000000       3.000000
# max    998553.000000  1.528089e+09       6.000000       4.000000
#
#                 pkts          bytes   state_number         ltime  \
# count  996294.000000  996294.000000  996294.000000  9.962940e+05
# mean        6.520397     614.680508       2.826339  1.528083e+09
# std         8.635005     605.430161       1.210457  1.752813e+03
# min         1.000000     120.000000       1.000000  1.528081e+09
# ...

# %% [markdown]
# # Q7

# %%
df.head(3)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0      1.0  1.528089e+09     e          1.0   tcp           1.0
# 1      2.0  1.528089e+09     e          1.0   arp           2.0
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr  sport            daddr dport  ...  AR_P_Proto_P_SrcIP  \
# 0  192.168.100.147  49960    192.168.100.7    80  ...            1.142970
# 1    192.168.100.7     -1  192.168.100.147    -1  ...            0.003857
# 2  192.168.100.147  49962    192.168.100.7    80  ...            1.142970
#
#    AR_P_Proto_P_DstIP N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# 0             1.12704              96.0               75.0
# 1         15267.20000               1.0                2.0
# 2             1.12704              96.0               75.0
#
#    AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 0            1.133720            1.129970                             770.0
# ...

# %% [markdown]
# # Q8

# %%
df.tail(4)
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport          daddr dport  ...  AR_P_Proto_P_SrcIP  \
# 998549  192.168.100.149  24882  192.168.100.5    80  ...            0.269102
# 998550  192.168.100.149  24883  192.168.100.5    80  ...            0.269102
# 998551  192.168.100.149  24884  192.168.100.5    80  ...            0.269102
# 998552  192.168.100.149  24885  192.168.100.5    80  ...            0.269102
#
#         AR_P_Proto_P_DstIP N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# 998549            0.269102             100.0              100.0
# 998550            0.269102             100.0              100.0
# ...

# %% [markdown]
# # Q9

# %%
df.loc[df['proto']=='UDP'].head(1)
# Out:
#    pkSeqID         stime flags  flgs_number proto  proto_number  \
# 2      3.0  1.528089e+09     e          1.0   UDP           1.0
#
#              saddr  sport          daddr dport  ...  AR_P_Proto_P_SrcIP  \
# 2  192.168.100.147  49962  192.168.100.7    80  ...             1.14297
#
#    AR_P_Proto_P_DstIP N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# 2             1.12704              96.0               75.0
#
#    AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  Pkts_P_State_P_Protocol_P_DestIP  \
# 2              1.1351             1.12997                             770.0
#
#    Pkts_P_State_P_Protocol_P_SrcIP  category  subcategory
# 2                            602.0       DoS         HTTP
#
# [1 rows x 45 columns]

# %% [markdown]
# # Q10

# %%
print('Rows : ',df.shape[0])
# Out:
# Rows :  996294

# %% [markdown]
# # Q11

# %%
df.iloc[:, : 5].head(1)
# Out:
#    pkSeqID         stime flags  flgs_number proto
# 0      1.0  1.528089e+09     e          1.0   tcp

# %% [markdown]
# # Q12

# %%
gb=df.loc[df['flags']=='i']
print('Packets with flag i: ',gb.shape[0])
# Out:
# Packets with flag i:  30

# %% [markdown]
# # Q13a

# %%
g1=df.loc[df['Pkts_P_State_P_Protocol_P_DestIP']+df['Pkts_P_State_P_Protocol_P_SrcIP']<=10]
g1
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 1            2.0  1.528089e+09     e          1.0   arp           2.0
# 77          78.0  1.528089e+09     e          1.0   arp           2.0
# 146        147.0  1.528089e+09     e          1.0   tcp           1.0
# 295        296.0  1.528089e+09     e          1.0   arp           2.0
# 296        297.0  1.528089e+09     e          1.0   arp           2.0
# ...          ...           ...   ...          ...   ...           ...
# 632157  632158.0  1.528085e+09     e          1.0   arp           2.0
# 835436  835437.0  1.528085e+09     e          1.0   arp           2.0
# 840544  840545.0  1.528085e+09     e          1.0   arp           2.0
# 840672  840673.0  1.528085e+09     e          1.0   arp           2.0
# 843637  843638.0  1.528085e+09     e          1.0   arp           2.0
#
#                   saddr  sport            daddr dport  ...  \
# 1         192.168.100.7     -1  192.168.100.147    -1  ...
# ...

# %%
g2=df.loc[df['Pkts_P_State_P_Protocol_P_DestIP']+df['Pkts_P_State_P_Protocol_P_SrcIP']>10]
g2
# Out:
#          pkSeqID         stime flags  flgs_number proto  proto_number  \
# 0            1.0  1.528089e+09     e          1.0   tcp           1.0
# 2            3.0  1.528089e+09     e          1.0   UDP           1.0
# 3            4.0  1.528089e+09     i          1.0   tcp           1.0
# 4            5.0  1.528089e+09     e          1.0   UDP           1.0
# 6            7.0  1.528089e+09     i          1.0   tcp           1.0
# ...          ...           ...   ...          ...   ...           ...
# 998548  998549.0  1.528085e+09     e          1.0   udp           3.0
# 998549  998550.0  1.528085e+09     e          1.0   udp           3.0
# 998550  998551.0  1.528085e+09     e          1.0   udp           3.0
# 998551  998552.0  1.528085e+09     e          1.0   udp           3.0
# 998552  998553.0  1.528085e+09     e          1.0   udp           3.0
#
#                   saddr  sport          daddr dport  ...  AR_P_Proto_P_SrcIP  \
# ...

# %% [markdown]
# # Q13b

# %% [markdown]
# 13(a)

# %%
df['stime'].mean()
# Out:
# 1528082733.2621455

# %% [markdown]
# 13(b)

# %%
df['sbytes'].mean()
# Out:
# 583.0793902201559

# %% [markdown]
# 13(c)

# %%
df['dbytes'].mean()
# Out:
# 31.60111774235316

# %% [markdown]
# # Q14

# %%
df[(df['subcategory']=='HTTP') | df['subcategory']=='TCP'].mean()
df[(df['subcategory']=='HTTP') | df['subcategory']=='TCP'].var()
# Out:
# pkSeqID                             NaN
# stime                               NaN
# flags                               NaN
# flgs_number                         NaN
# proto                               NaN
# proto_number                        NaN
# saddr                               NaN
# sport                               NaN
# daddr                               NaN
# dport                               NaN
# pkts                                NaN
# bytes                               NaN
# state                               NaN
# state_number                        NaN
# ltime                               NaN
# seq                                 NaN
# dur                                 NaN
# mean                                NaN
# stddev                              NaN
# sum                                 NaN
# min                                 NaN
# max                                 NaN
# spkts                               NaN
# ...

# %% [markdown]
# # Q15

# %%
df['stime'].hist()
